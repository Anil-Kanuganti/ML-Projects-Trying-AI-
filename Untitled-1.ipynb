# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('train.csv')
df.info()
df.describe()
df['Age'].hist()
sns.heatmap(df.isnull())
df.groupby('Survived')['Age'].mean()
df.shape
df.columns
df.dtypes
df.head(10)
df.isnull().sum()
df['Age'].fillna(df['Age'].sum())
df.dropna(subset=['Embarked'])
df[df['Survived']==1]
df[df['Age']>30]
df.sort_values('Fare', ascending=False).head(10)
df.groupby('Sex')['Survived'].mean()
df.groupby('Pclass')['Survived'].mean()
df.groupby('Pclass')['Fare'].mean()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# Pclass
# 1    84.154687
# 2    20.662183
# 3    13.675550
# Name: Fare, dtype: float64

# %% [markdown]
# ## Who survived?
# Women survived at 74% rate vs men at only 19%.
# First class passengers survived more than third class.

# %% [markdown]
# ## Looking at missing data
# The dataset has 891 rows. Age has 177 missing values — that's 20% of the data.
# Cabin is almost entirely missing so we'll likely drop it later.
